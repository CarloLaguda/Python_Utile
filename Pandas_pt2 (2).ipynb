# %% [markdown]
# # Pandas pt2

# %% [markdown]
# ## Esercitazione guidata

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas

# %%
df = pandas.read_csv("vgsales new.csv")

# %%
df
# Out:
#         Rank                         Name Platform    Year         Genre  \
# 0        259                    Asteroids     2600  1980.0       Shooter
# 1        545              Missile Command     2600  1980.0       Shooter
# 2       1768                      Kaboom!     2600  1980.0          Misc
# 3       1971                     Defender     2600  1980.0          Misc
# 4       2671                       Boxing     2600  1980.0      Fighting
# ...      ...                          ...      ...     ...           ...
# 16593  16310                Freaky Flyers       GC     NaN        Racing
# 16594  16330                    Inversion       PC     NaN       Shooter
# 16595  16369  Hakuouki: Shinsengumi Kitan      PS3     NaN     Adventure
# 16596  16430                 Virtua Quest       GC     NaN  Role-Playing
# 16597  16496                   The Smurfs      3DS     NaN        Action
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Visualizziamo i valori nulli del dataframe

# %%
df.isnull()
# Out:
#         Rank   Name  Platform   Year  Genre  Publisher  NA_Sales  EU_Sales  \
# 0      False  False     False  False  False      False     False     False
# 1      False  False     False  False  False      False     False     False
# 2      False  False     False  False  False      False     False     False
# 3      False  False     False  False  False      False     False     False
# 4      False  False     False  False  False      False     False     False
# ...      ...    ...       ...    ...    ...        ...       ...       ...
# 16593  False  False     False   True  False      False     False     False
# 16594  False  False     False   True  False      False     False     False
# 16595  False  False     False   True  False      False     False     False
# 16596  False  False     False   True  False      False     False     False
# 16597  False  False     False   True  False      False     False     False
#
#        JP_Sales  Other_Sales  Global_Sales
# ...

# %% [markdown]
# ## Vediamo meglio dove si trovano

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %% [markdown]
# #### I valori nulli nell'analisi dei dati ci danno problemi
# #### quindi creiamo un nuovo dataframe a partine da questo
# #### levando i valori nulli

# %%
df_pulito = df.dropna() #.dropna() rimuove le righe che contengono valori null
df_pulito.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16291 entries, 0 to 16326
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  float64
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
df_pulito.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %% [markdown]
# ## Esporto il nuovo dataframe
#
# index = false -> non ci salva anche l'indice del dataframe
# sep -> il separatore

# %%
df_pulito.to_csv('dati_puliti.csv', index=False, sep=';')

# %% [markdown]
# ## Ordiniamo il dataframe in ordine di "Rank"

# %% [markdown]
# ### Seleziona tutti i giochi usciti dopo il 2000 della categoria Shooter, e stampa i primi 5 e gli ultimi 5.

# %%
#visualizza i primi 5

# %%
#visualizza gli ultimi 5

# %% [markdown]
# ### dataframe[colonna].str.contains("parola") -> selezioniamo le righe della colonna che la contengono la parola
# case = false (opzionale) -> ignora maiuscole e minuscole

# %%
df_pulito[df_pulito['Name'].str.contains('pokemon', case=False)]
# Out:
#         Rank                                               Name Platform  \
# 705        5                           Pokemon Red/Pokemon Blue       GB
# 1636      13                        Pokemon Gold/Pokemon Silver       GB
# 1641     166                                    Pokemon Stadium      N64
# 1642     172                                    Pokemon Pinball       GB
# 1649     347                                       Pokemon Snap      N64
# 2086    4367                              Pokemon Puzzle League      N64
# 2410    2338              Pokemon Card GB2: Here Comes Team GR!       GB
# 2806      26                      Pokemon Ruby/Pokemon Sapphire      GBA
# 3686    1194                   Pokemon Pinball: Ruby & Sapphire      GBA
# 3880    5052                                    Pokemon Channel       GC
# 3948    6233                       Pokemon Box: Ruby & Sapphire       GC
# 4411      59                  Pokemon FireRed/Pokemon LeafGreen      GBA
# ...

# %% [markdown]
# #### Seleziona tutti i giochi Call of Duty e classificali per maggior numero di vendite sul mercato europeo

# %% [markdown]
# ## Cosa ci manca da vedere?
# ### -Rinominare una colonna
# ### -Creare una nuova colonna (series)
# ### Basta poi possiamo anche fissare la verifica

# %% [markdown]
# ## Rinominare una colonna
# ### Usiamo il metodo .rename()
# Sintassi nomedataframe.rename(columns = { "colonna1" : "colonna1Rinominata" , "colonna2" : "colonna2Rinominata" , ....  })

# %%
df_pulito.rename(columns={'Genre': 'Genere'})
# Out:
#         Rank                                               Name Platform  \
# 0        259                                          Asteroids     2600
# 1        545                                    Missile Command     2600
# 2       1768                                            Kaboom!     2600
# 3       1971                                           Defender     2600
# 4       2671                                             Boxing     2600
# ...      ...                                                ...      ...
# 16322  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16323  14393   Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16324  16244   Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 16325  16441                   Brothers Conflict: Precious Baby      PSV
# 16326   5959                             Imagine: Makeup Artist       DS
#
#          Year        Genere        Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# # Aggiungere una nuova colonna

# %% [markdown]
# ![image.png](attachment:90f864d0-eba3-4aca-9d88-ad70c4603eab.png)

# %% [markdown]
# ### Ci sono tanti modi...
# ### come dataframe.insert() ,
# ### creare un dizionario e aggiungerlo ad dataframe...MA

# %% [markdown]
# ### Se un dataframe ha 1k di righe dobbiamo aggiungere 1k elementi a mano....
# ### QUINDI:

# %% [markdown]
# ## Utilizziamo dataframe.loc()
# ### Utilizzando .loc[] -> è possibile aggiungere una nuova colonna direttamente o modificare i valori in base a delle condizioni

# %% [markdown]
# ### sintassi: df.loc[df['colonna'] condizione , 'nuovacolonna'] = valore

# %%
df_pulito
# Out:
#         Rank                                               Name Platform  \
# 0        259                                          Asteroids     2600
# 1        545                                    Missile Command     2600
# 2       1768                                            Kaboom!     2600
# 3       1971                                           Defender     2600
# 4       2671                                             Boxing     2600
# ...      ...                                                ...      ...
# 16322  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16323  14393   Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16324  16244   Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 16325  16441                   Brothers Conflict: Precious Baby      PSV
# 16326   5959                             Imagine: Makeup Artist       DS
#
#          Year         Genre        Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ### Per esempio....

# %%
# aggiungiamo una nuova colonna in base alle vendite
# diciamo che se la colonna Global_Sales è:
# maggiore uguale di 1 allora ha venduto tanto
# altrimenti ha venduto poco
df_pulito.loc[df['Global_Sales'] >= 1, 'vendite'] = 'Tanto'
df_pulito.loc[df['Global_Sales'] < 1, 'vendite'] = 'Poco'
df_pulito
# Out:
#         Rank                                               Name Platform  \
# 0        259                                          Asteroids     2600
# 1        545                                    Missile Command     2600
# 2       1768                                            Kaboom!     2600
# 3       1971                                           Defender     2600
# 4       2671                                             Boxing     2600
# ...      ...                                                ...      ...
# 16322  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16323  14393   Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16324  16244   Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 16325  16441                   Brothers Conflict: Precious Baby      PSV
# 16326   5959                             Imagine: Makeup Artist       DS
#
#          Year         Genre        Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...
