# %% [markdown]
# ## Verifica su Pandas: FILA A

# %% [markdown]
# ### Consegna e valutazione
# 1. Consegnare tutti i dispositivi smart
# 2. Scaricare il dataset allegato
# 3. Effettuare la consegna del notebook entro il termine prestabilito, rimoninandolo con il vostro cognome
# 4. La valutazione finale va da 1 a 10. Il punteggio per ogni esercizio è indicato nella relativa parte
# 5. I compiti non consegnati o in riardo o non leggibili verranno valutati 1
# 6. I compiti svolti per la fila sbagliati o copiati verranno valutati 1

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# ## Esercizi prima parte [0.5 punti per esercizio]

# %% [markdown]
# 1. Importare il dataset 'netflix_titles.csv' e visualizzarne le prime 5 righe

# %%
df = pd.read_csv("netflix_title.csv")

# %% [markdown]
# 2. Visualizzare tutte le colonne del dataset con il relativo tipo

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# 3. Trovare il film che ha come id 's7078'

# %%
df[df["show_id"] == "s7078"]
# Out:
#      show_id   type                 title           director  \
# 7077   s7078  Movie  Inglourious Basterds  Quentin Tarantino
#
#                                                    cast  \
# 7077  Brad Pitt, Mélanie Laurent, Christoph Waltz, E...
#
#                      country     date_added  release_year rating duration  \
# 7077  Germany, United States  July 22, 2019          2009      R  153 min
#
#                listed_in                                        description
# 7077  Action & Adventure  A Jewish cinema owner in occupied Paris is for...

# %% [markdown]
# 4. Visualizzare il numero di elementi nulli del dataset

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# 5. Creare una nuova colonna chiamata 'After_2000' che indica se lo show è stato prodotto dopo l'anno 2000 oppure no

# %%
df.loc[df["release_year"] >=2000,  "After_2000"]= "True"
df.loc[df["release_year"] <2000,  "After_2000"]= "False"
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# 6. Rinominare le colonne 'title' in 'titolo' e 'type' in 'tipo'

# %%
df.rename(columns={"title": "titolo", "type": "tipo"})
# Out:
#      show_id     tipo                 titolo         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# 7. Impostare la colonna 'show_id' come indice e ordinare il dataset per titolo

# %% [markdown]
# 8. Trovare l'anno massimo del dataset

# %%
df["release_year"].max()
# Out:
# 2021

# %% [markdown]
# ## Esercizi seconda parte [1 punto per esercizio]

# %% [markdown]
# 1. Trovare tutti gli show prodotti in America e in Italia

# %%
df[(df["country"] == "United States") | (df["country"] == "Italy")]
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 9        s10    Movie          The Starling   Theodore Melfi
# 15       s16  TV Show     Dear White People              NaN
# 27       s28    Movie             Grown Ups     Dennis Dugan
# 28       s29    Movie            Dark Skies    Scott Stewart
# ...      ...      ...                   ...              ...
# 8791   s8792    Movie           Young Adult    Jason Reitman
# 8793   s8794    Movie  Yours, Mine and Ours     Raja Gosnell
# 8802   s8803    Movie                Zodiac    David Fincher
# 8804   s8805    Movie            Zombieland  Ruben Fleischer
# 8805   s8806    Movie                  Zoom     Peter Hewitt
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# ...

# %% [markdown]
# 2. Contare quanti sono i film e le serie tv presenti nel dataset

# %%
df["type"].count()
# Out:
# 8807

# %% [markdown]
# 3. Contare quanti sono gli show (film + serie TV) prodotti in America per ogni regista

# %%
df[df["country"] == "United States"].groupby("director").size()
# Out:
# director
# Aaron Hann, Mario Miscione    1
# Aaron Lieber                  1
# Aaron Nee, Adam Nee           1
# Abby Epstein                  1
# Adam Bolt                     1
#                              ..
# Zak Hilditch                  2
# Zatella Beatty                1
# Zeke Norton                   1
# Zoe Lister-Jones              1
# Àlex Pastor, David Pastor     1
# Length: 1560, dtype: int64

# %% [markdown]
# 4. Contare quanti sono gli show (film + serie TV) prodotti per ogni Paese e visualizzare solo quelli che hanno almeno 10 film

# %%
df.groupby("country").size()[df.groupby("country").size() >= 10]
# Out:
# country
# Argentina                          56
# Australia                          87
# Australia, United States           13
# Brazil                             77
# Canada                            181
# Canada, United States              45
# Chile                              14
# China                              66
# China, Hong Kong                   14
# Colombia                           35
# Denmark                            13
# Egypt                             106
# France                            124
# France, Belgium                    27
# France, United States              10
# Germany                            67
# Germany, United States             13
# Hong Kong                          53
# Hong Kong, China                   16
# India                             972
# India, United States               10
# Indonesia                          79
# Ireland                            10
# Israel                             13
# ...

# %% [markdown]
# 5. Contare quante sono le serie TV prodotte per ogni Paese e visualizzare solo quelli che hanno almeno 20 serie

# %%
# Out:
# [Series([], dtype: bool)]
